# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from time import time
import warnings
warnings.filterwarnings("ignore")

plt.style.use('ggplot')

# %%
data = pd.read_csv('Sales_Data - Sales_Data.csv', parse_dates=['Order Date'], index_col='Order Date')
data.head()
# Out:
#             Customer ID         Category Sub-Category      Sales  Quantity  \
# Order Date
# 2014-05-10    AH-690134  Office Supplies      Storage    13.2000         2
# 2012-08-15  AM-10360139       Technology       Phones  4453.0500         7
# 2015-08-29   BV-1124528        Furniture       Tables  2320.6400         5
# 2015-05-07  TC-21475130       Technology  Accessories   346.5882         9
# 2013-05-10   BW-1111058       Technology  Accessories   334.6800         4
#
#             Discount  Marketing  Sales Compensation  Returned
# Order Date
# 2014-05-10      0.60       0.00                1.42     False
# 2012-08-15      0.00    1424.85              433.41     False
# 2015-08-29      0.20       0.00              130.77     False
# 2015-05-07      0.47       0.00               21.13     False
# 2013-05-10      0.00      83.64               63.87     False

# %% [markdown]
# ### Looking at the categories

# %%
data['Category'].unique()
# Out:
# array(['Office Supplies', 'Technology', 'Furniture'], dtype=object)

# %%
# number of sales by category

data.groupby('Category')['Sales'].count()
# Out:
# Category
# Furniture           6827
# Office Supplies    21887
# Technology          7189
# Name: Sales, dtype: int64

# %% [markdown]
# # Predicting technology sales
#
# ### Preparing the dataframe

# %%
tech = data[data['Category'] == 'Technology'][['Sales']]

tech_ms = tech.resample('M').sum()
tech_ms.tail()
# Out:
#                    Sales
# Order Date
# 2015-08-31  124488.49538
# 2015-09-30  130498.87822
# 2015-10-31  105366.33922
# 2015-11-30  168708.92626
# 2015-12-31  113237.84520

# %%
tech_ms.plot(figsize=(14,6));

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

seasonal_decompose(tech_ms, period=12).plot();

# %% [markdown]
# ### Splitting the dataframe into test and train

# %%
df_train = tech_ms[:len(tech_ms)-11]
df_test = tech_ms[(len(tech_ms)-11):]

# %% [markdown]
# ### Testing for stationarity

# %%
adfuller(df_train)
# Out:
# (-3.627012882399627,
#  0.005265110189456989,
#  0,
#  36,
#  {'1%': -3.626651907578875,
#   '5%': -2.9459512825788754,
#   '10%': -2.6116707716049383},
#  602.0180894342894)

# %%
df_train_diff = df_train.diff().dropna()

# %%
adfuller(df_train_diff)
# Out:
# (-6.389640603853545,
#  2.1215606991733676e-08,
#  10,
#  25,
#  {'1%': -3.7238633119999998, '5%': -2.98648896, '10%': -2.6328004},
#  561.4369430549689)

# %% [markdown]
# ### Searching over model orders

# %%
import pmdarima as pm

results = pm.auto_arima(df_train, d=1, seasonal=True, m=12, information_criterion='aic')
results
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(0, 1, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %% [markdown]
# ### Fitting the model

# %%
model = SARIMAX(df_train, order=(0, 1, 1), seasonal_order=(0, 1, 0, 12))
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Sales   No. Observations:                   37
# Model:             SARIMAX(0, 1, 1)x(0, 1, [], 12)   Log Likelihood                -268.635
# Date:                             Sun, 30 May 2021   AIC                            541.269
# Time:                                     21:10:04   BIC                            543.625
# Sample:                                 01-31-2012   HQIC                           541.894
#                                       - 01-31-2015
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5875      0.143     -4.122      0.000      -0.867      -0.308
# sigma2       3.08e+08   4.72e-11   6.52e+18      0.000    3.08e+08    3.08e+08
# ===================================================================================
# Ljung-Box (Q):                       27.08   Jarque-Bera (JB):                 1.79
# Prob(Q):                              0.25   Prob(JB):                         0.41
# Heteroskedasticity (H):               1.71   Skew:                             0.53
# Prob(H) (two-sided):                  0.46   Kurtosis:                         3.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
# """

# %%
results.plot_diagnostics(figsize=(14,8));

# %% [markdown]
# ### Getting the forecast

# %%
forecast = results.get_forecast(steps=12)

predictions = forecast.predicted_mean
ci = forecast.conf_int(alpha=0.05)

# observed plot
fig = tech_ms.plot(label='observed', figsize=(14,7))
fig.set_xlabel('Date')
fig.set_ylabel('Total Monthly Sales')
fig.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='k', alpha=0.2)

# prediction plot
predictions.plot(ax=fig, label='Predictions', alpha=0.7, figsize=(14,7))
plt.legend();

# %%
predictions.tail(1)
# Out:
# 2016-01-31    90864.291964
# Freq: M, dtype: float64

# %% [markdown]
# # Predicting furniture sales
#
# ### Preparing the dataframe

# %%
furniture = data[data['Category'] == 'Furniture'][['Sales']]

furniture_ms = furniture.resample('M').sum()
furniture_ms.tail()
# Out:
#                   Sales
# Order Date
# 2015-08-31   91282.5484
# 2015-09-30  126734.3301
# 2015-10-31  101381.0088
# 2015-11-30  117411.3199
# 2015-12-31  111702.8194

# %%
furniture_ms.plot(figsize=(14,6));

# %%
seasonal_decompose(furniture_ms, period=12).plot();

# %% [markdown]
# ### Splitting the dataframe into test and train

# %%
df_train = furniture_ms[:len(furniture_ms)-11]
df_test = furniture_ms[(len(furniture_ms)-11):]

# %% [markdown]
# ### Testing for stationarity

# %%
adfuller(df_train)
# Out:
# (0.39501018007729816,
#  0.9813073785438525,
#  10,
#  26,
#  {'1%': -3.7112123008648155,
#   '5%': -2.981246804733728,
#   '10%': -2.6300945562130176},
#  582.8254354563362)

# %%
df_train_diff = df_train.diff().dropna()

# %%
adfuller(df_train_diff)
# Out:
# (-4.695048727544003,
#  8.59736266476181e-05,
#  10,
#  25,
#  {'1%': -3.7238633119999998, '5%': -2.98648896, '10%': -2.6328004},
#  553.0122206604034)

# %% [markdown]
# ### Searching over model orders

# %%
results = pm.auto_arima(df_train, d=1, seasonal=True, m=12, information_criterion='aic')
results
# Out:
# ARIMA(order=(0, 1, 2), scoring_args={}, seasonal_order=(1, 1, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %% [markdown]
# ### Fitting the model

# %%
model = SARIMAX(df_train, order=(0, 1, 2), seasonal_order=(1, 1, 0, 12))
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Sales   No. Observations:                   37
# Model:             SARIMAX(0, 1, 2)x(1, 1, [], 12)   Log Likelihood                -256.411
# Date:                             Sun, 30 May 2021   AIC                            520.821
# Time:                                     21:11:33   BIC                            525.533
# Sample:                                 01-31-2012   HQIC                           522.071
#                                       - 01-31-2015
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.1409      0.143     -0.987      0.324      -0.421       0.139
# ma.L2         -0.1817      0.269     -0.674      0.500      -0.710       0.346
# ar.S.L12      -0.5104      0.140     -3.649      0.000      -0.785      -0.236
# sigma2       1.13e+08   4.69e-10   2.41e+17      0.000    1.13e+08    1.13e+08
# ===================================================================================
# Ljung-Box (Q):                       23.78   Jarque-Bera (JB):                 1.85
# Prob(Q):                              0.42   Prob(JB):                         0.40
# Heteroskedasticity (H):               0.72   Skew:                             0.65
# Prob(H) (two-sided):                  0.65   Kurtosis:                         3.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.11e+33. Standard errors may be unstable.
# """

# %%
results.plot_diagnostics(figsize=(14,8));

# %% [markdown]
# ### Getting the forecast

# %%
forecast = results.get_forecast(steps=12)

predictions = forecast.predicted_mean
ci = forecast.conf_int(alpha=0.05)

# observed plot
fig = furniture_ms.plot(label='observed', figsize=(14,7))
fig.set_xlabel('Date')
fig.set_ylabel('Total Monthly Sales')
fig.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='k', alpha=0.2)

# prediction plot
predictions.plot(ax=fig, label='Predictions', alpha=0.7, figsize=(14,7))
plt.legend();

# %%
predictions.tail(1)
# Out:
# 2016-01-31    68905.511209
# Freq: M, dtype: float64

# %% [markdown]
# # Predicting the sales of office supplies
#
# ### Preparing the dataframe

# %%
office = data[data['Category'] == 'Office Supplies'][['Sales']]

# resampling the data
office_ms = office.resample('M').sum()
office_ms.tail()
# Out:
#                   Sales
# Order Date
# 2015-08-31  113687.2656
# 2015-09-30   89736.5053
# 2015-10-31   83018.8556
# 2015-11-30  105578.5775
# 2015-12-31  111932.1272

# %%
office_ms.plot(figsize=(14,6));

# %%
seasonal_decompose(office_ms, period=12).plot();

# %% [markdown]
# ### Splitting the dataframe into test and train

# %%
df_train = office_ms[:len(office_ms)-11]
df_test = office_ms[(len(office_ms)-11):]

# %% [markdown]
# ### Testing for stationarity

# %%
adfuller(df_train)
# Out:
# (-2.379848337293893,
#  0.14750502691220996,
#  3,
#  33,
#  {'1%': -3.6461350877925254,
#   '5%': -2.954126991123355,
#   '10%': -2.6159676124885216},
#  583.7240925065573)

# %%
df_train_diff = df_train.diff().dropna()

# %%
adfuller(df_train_diff)
# Out:
# (-4.344801054842013,
#  0.00037121382463625594,
#  10,
#  25,
#  {'1%': -3.7238633119999998, '5%': -2.98648896, '10%': -2.6328004},
#  557.6616375794965)

# %% [markdown]
# ### Searching over model orders

# %%
import pmdarima as pm

# %%
results = pm.auto_arima(df_train, d=1, seasonal=True, m=12, information_criterion='aic')
results
# Out:
# ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(1, 1, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %% [markdown]
# ### Fitting the model

# %%
model = SARIMAX(df_train, order=(0, 1, 1), seasonal_order=(1, 1, 0, 12))
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               Sales   No. Observations:                   37
# Model:             SARIMAX(0, 1, 1)x(1, 1, [], 12)   Log Likelihood                -262.997
# Date:                             Sun, 30 May 2021   AIC                            531.995
# Time:                                     21:12:22   BIC                            535.529
# Sample:                                 01-31-2012   HQIC                           532.932
#                                       - 01-31-2015
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5125      0.140     -3.654      0.000      -0.787      -0.238
# ar.S.L12      -0.3902      0.164     -2.379      0.017      -0.712      -0.069
# sigma2      2.068e+08   1.15e-10    1.8e+18      0.000    2.07e+08    2.07e+08
# ===================================================================================
# Ljung-Box (Q):                        9.27   Jarque-Bera (JB):                 0.25
# Prob(Q):                              0.99   Prob(JB):                         0.88
# Heteroskedasticity (H):               0.41   Skew:                             0.23
# Prob(H) (two-sided):                  0.23   Kurtosis:                         2.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
# """

# %%
results.plot_diagnostics(figsize=(16,8));

# %% [markdown]
# ### Getting the forecast

# %%
forecast = results.get_forecast(steps=12)

predictions = forecast.predicted_mean
ci = forecast.conf_int(alpha=0.05)

# observed plot
fig = office_ms.plot(label='observed', figsize=(14,7))
fig.set_xlabel('Date')
fig.set_ylabel('Total Monthly Sales')
fig.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='k', alpha=0.2)

# prediction plot
predictions.plot(ax=fig, label='Predictions', alpha=0.7, figsize=(14,7))
plt.legend();

# %%
predictions.tail(1)
# Out:
# 2016-01-31    63315.835279
# Freq: M, dtype: float64

# %% [markdown]
# # Predicting aggregate sales
#
# ### Preparing the dataframe

# %%
data.head()
# Out:
#             Customer ID         Category Sub-Category      Sales  Quantity  \
# Order Date
# 2014-05-10    AH-690134  Office Supplies      Storage    13.2000         2
# 2012-08-15  AM-10360139       Technology       Phones  4453.0500         7
# 2015-08-29   BV-1124528        Furniture       Tables  2320.6400         5
# 2015-05-07  TC-21475130       Technology  Accessories   346.5882         9
# 2013-05-10   BW-1111058       Technology  Accessories   334.6800         4
#
#             Discount  Marketing  Sales Compensation  Returned
# Order Date
# 2014-05-10      0.60       0.00                1.42     False
# 2012-08-15      0.00    1424.85              433.41     False
# 2015-08-29      0.20       0.00              130.77     False
# 2015-05-07      0.47       0.00               21.13     False
# 2013-05-10      0.00      83.64               63.87     False

# %%
sales = data[['Sales']].resample('M').sum()
sales.head()
# Out:
#                    Sales
# Order Date
# 2012-01-31   71858.54326
# 2012-02-29   68278.82394
# 2012-03-31   87217.28850
# 2012-04-30   71783.22218
# 2012-05-31  110770.85780

# %%
seasonal_decompose(sales, period=12).plot();

# %% [markdown]
# ### Splitting the dataframe into test and train

# %%
df_train = sales[:len(sales)-11]
df_test = sales[(len(sales)-11):]

# %% [markdown]
# ### Testing for stationarity

# %%
adfuller(df_train)
# Out:
# (0.25253041261734543,
#  0.9750586648881077,
#  10,
#  26,
#  {'1%': -3.7112123008648155,
#   '5%': -2.981246804733728,
#   '10%': -2.6300945562130176},
#  643.6064695947525)

# %%
df_train_diff = df_train.diff().dropna()

# %%
adfuller(df_train_diff)
# Out:
# (-8.264146236336527,
#  4.990680866265615e-13,
#  10,
#  25,
#  {'1%': -3.7238633119999998, '5%': -2.98648896, '10%': -2.6328004},
#  589.4544914120593)

# %%
results = pm.auto_arima(df_train, d=1, seasonal=True, m=12, information_criterion='aic')
results
# Out:
# ARIMA(order=(0, 1, 0), scoring_args={}, seasonal_order=(1, 1, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %% [markdown]
# ### Fitting the model

# %%
model = SARIMAX(df_train, order=(0, 1, 0), seasonal_order=(1, 1, 0, 12))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Sales   No. Observations:                   37
# Model:             SARIMAX(0, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -283.522
# Date:                            Sun, 30 May 2021   AIC                            571.043
# Time:                                    21:13:07   BIC                            573.399
# Sample:                                01-31-2012   HQIC                           571.668
#                                      - 01-31-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.1179      0.174     -0.677      0.499      -0.460       0.224
# sigma2      1.152e+09   1.51e-11   7.63e+19      0.000    1.15e+09    1.15e+09
# ===================================================================================
# Ljung-Box (Q):                       23.09   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.46   Prob(JB):                         0.71
# Heteroskedasticity (H):               1.40   Skew:                             0.34
# Prob(H) (two-sided):                  0.65   Kurtosis:                         3.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.46e+35. Standard errors may be unstable.
# """

# %%
results.plot_diagnostics(figsize=(16,8));

# %% [markdown]
# ### Getting the forecasts

# %%
forecast = results.get_forecast(steps=12)

predictions = forecast.predicted_mean
ci = forecast.conf_int(alpha=0.05)

# observed plot
fig = sales.plot(label='observed', figsize=(14,7))
fig.set_xlabel('Date')
fig.set_ylabel('Total Monthly Sales')
fig.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='k', alpha=0.2)

# prediction plot
predictions.plot(ax=fig, label='Predictions', alpha=0.7, figsize=(14,7))
plt.legend();

# %%
predictions.tail(1)
# Out:
# 2016-01-31    218029.8209
# Freq: M, dtype: float64
